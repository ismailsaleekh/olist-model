# %% [markdown]
# # 05 - GCP Deployment & MLOps
#
# **Day 4 Objectives:**
# 1. Local inference testing
# 2. Upload model artifacts to Cloud Storage
# 3. Register model in Vertex AI Model Registry
# 4. Create and deploy endpoint
# 5. Test deployed endpoint
# 6. Configure model monitoring
# 7. Create Vertex AI Pipeline
# 8. Setup CI/CD (optional)

# %%
# TODO: Implement in Day 4
